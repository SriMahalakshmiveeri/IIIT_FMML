# %% [markdown]
# <a href="https://colab.research.google.com/github/SriMahalakshmiveeri/IIIT_FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 12:51:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   157MB/s    in 0.4s
#
# 2024-03-30 12:51:37 (157 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3375   1606.07575v1  Pruning of redundant or irrelevant instances o...  stat
# 12544  1802.09128v1  We consider the minimization of a function def...    cs
# 10274   1102.1465v6  Prediction markets are used in real life to pr...  stat
# 10738   1305.5782v1  We generalize the stochastic block model to th...  stat
# 25920  1512.04958v1  Quantification of adipose tissue (fat) from co...    cs
# ...             ...                                                ...   ...
# 39632  1611.00287v2  Structured illumination microscopy (SIM) impro...    cs
# 7091   1710.03444v1  In several domains obtaining class annotations...  stat
# 18248   0705.0197v1  Gaussian mixture models (GMM) and support vect...    cs
# 9357    1412.4271v2  Arriving at the complete probabilistic knowled...    cs
# 35133  cs/9810005v1  Coalition formation is a key topic in multiage...    cs
#
#                                                    title  year  \
# 3375   Multipartite Ranking-Selection of Low-Dimensio...  2016
# 12544  Averaging Stochastic Gradient Descent on Riema...  2018
# 10274  An Introduction to Artificial Prediction Marke...  2011
# 10738  Adapting the Stochastic Block Model to Edge-We...  2013
# 25920  Context Driven Label Fusion for segmentation o...  2015
# ...                                                  ...   ...
# 39632  Structured illumination microscopy with unknow...  2016
# 7091   Safe Semi-Supervised Learning of Sum-Product N...  2017
# 18248  Fault Classification in Cylinders Using Multil...  2007
# 9357   Multi-Context Models for Reasoning under Parti...  2014
# 35133  Anytime Coalition Structure Generation with Wo...  1998
#
#                                                 keywords
# 3375   [redundant, irrelevant, instances, successful,...
# 12544  [minimization, riemannian, accessible, estimat...
# 10274  [prediction, presidential, elections, mathemat...
# 10738  [generalize, stochastic, important, annotated,...
# 25920  [quantification, tomography, conducted, automa...
# ...                                                  ...
# 39632  [structured, illumination, microscopy, resolut...
# 7091   [obtaining, annotations, expensive, unlabelled...
# 18248  [introduced, population, cylindrical, procedur...
# 9357   [probabilistic, knowledge, variables, demandin...
# 35133  [coalition, formation, multiagent, coalition, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3375     [redundant, irrelevant, instances, successful,...
# 12544    [minimization, riemannian, accessible, estimat...
# 10274    [prediction, presidential, elections, mathemat...
# 10738    [generalize, stochastic, important, annotated,...
# 25920    [quantification, tomography, conducted, automa...
#                                ...
# 26167    [engagement, manipulating, interfaces, importa...
# 384      [introduce, probabilistic, programming, compli...
# 21712    [classifier, unlabeled, inductive, transductiv...
# 22401    [generalized, canonical, correlation, dimensio...
# 2675     [effective, heuristic, algorithm, computing, p...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8837 words.
# Out of those 4604 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="519a04b1-b745-4911-8e67-7543d69f02b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("519a04b1-b745-4911-8e67-7543d69f02b8")) {                    Plotly.newPlot(                        "519a04b1-b745-4911-8e67-7543d69f02b8",                        [{"x":["selecting","recognition","irrelevant","challenge","individual","descriptors","distinctions","available","similarity","supervised","selection","understanding","framework","improvements","dimensionality","thresholding","efficiency","multipartite","projection","considerable","performance","instances","successful","correlated","dimensional","redundant","experiments","application","manifolds","requiring","knowledge","demonstrate","geometric","algorithm","generated","gradients","geodesically","averaging","accessible","riemannian","converging","achieving","stochastic","euclidean","minimization","streaming","randomized","accelerate","estimates","transform","convergence","estimators","reasonable","mathematical","detection","estimator","specialized","artificial","efficient","presidential","comparisons","synthetic","regression","probability","generalizes","likelihood","aggregation","elections","algorithms","experimental","classifiers","mechanism","participate","numerical","presented","furthermore","extensive","assumptions","outperform","evaluation","classification","abdominal","introduction","participants","conditional","information","prediction","equations","previously","efficiently","approximates","exponential","posterior","introduce","outperforms","introduces","generalize","variational","threshold","generalization","distribution","important","technical","estimation","difficulties","annotated","structure","unsupervised","significant","quantification","automatic","conducted","tomography","deviation","refinement","appearance","reduction","automated","segmentation","consisting","completely","applications","perceived","reconstruct","preserving","disentangling","continuous","architecture","expression","significantly","manipulating","adversarial","attribute","different","naturalness","attributes","realistic","dependency","benchmarking","concurrent","decomposition","parallelism","implementations","attainable","depending","implement","convolutions","computationally","convolutional","computation","convergent","architectures","compatible","programming","processors","convolution","impossible","preserves","discretization","management","graphical","extremely","principle","distributions","convenient","diagnosis","representing","bioinformatics","description","extensively","relationships","intelligence","expressions","literature","moderately","difficult","variables","importance","financial","dependent","contingent","procedures","forecasting","parameters","timesteps","correlation","inference","quantities","successive","measurements","probabilistic","construct","approximate","conditions","encourage","clustering","covariance","extension","direction","empirical"],"y":[38,392,15,162,126,44,6,290,137,216,144,179,529,116,39,17,166,0,41,46,873,98,67,18,183,22,592,248,14,50,357,531,65,813,195,31,1,15,13,9,10,77,145,33,59,15,22,26,75,68,114,19,27,57,360,34,24,155,411,2,28,146,118,191,24,55,25,6,604,374,117,123,4,89,169,152,155,54,84,280,496,7,33,25,90,685,209,37,106,158,11,45,39,334,275,81,56,61,32,100,197,333,47,198,27,77,332,157,213,16,192,81,18,18,27,80,86,113,193,48,40,447,14,26,44,6,110,250,46,271,11,101,33,749,4,57,73,40,13,9,74,12,37,3,33,79,14,108,342,141,6,129,16,142,11,36,18,14,6,51,68,55,44,110,10,43,68,11,58,39,62,119,46,132,3,142,134,85,9,78,3,45,16,260,1,74,200,17,15,49,156,83,112,125,16,141,28,91,63,155],"type":"bar"},{"x":["selecting","recognition","irrelevant","challenge","individual" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4604,), (4604, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Users</span> <span style=''>prefer</span> <span style=''>Guetzli</span> <span style=''>JPEG</span> <span style=''>over</span> <span style=''>same</span> <span style=''>sized</span> <span style=''>libjpeg</span> <br/><br/><span style=''>We</span> <span style=''>report</span> <span style=''>on</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>by</span> <span style=''>human</span> <span style=''>raters</span> <span style=''>of</span> <span style=''>JPEG</span> <span style=''>images</span> <span style=''>from</span> <span style=''>libjpeg</span> <span style=''>and</span> <span style=''>our</span> <span style=''>new</span> <span style=''>Guetzli</span> <span style=''>encoder</span> <span style=''>Although</span> <span style=''>both</span> <span style=''>files</span> <span style=''>are</span> <span style=''>size</span> <span style=''>matched</span> <span style=''>75</span> <span style=''>of</span> <span style=''>ratings</span> <span style=''>are</span> <span style=''>in</span> <span style=''>favor</span> <span style=''>of</span> <span style=''>Guetzli</span> <span style=''>This</span> <span style=''>implies</span> <span style=''>the</span> <span style=''>Butteraugli</span> <span style=''>psychovisual</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>metric</span> <span style=''>which</span> <span style=''>guides</span> <span style=''>Guetzli</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reasonably</span> <span style=''>close</span> <span style=''>to</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.7);'>perception</span> <span style=''>at</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>levels</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>access</span> <span style=''>to</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>ratings</span> <span style=''>and</span> <span style=''>source</span> <span style=''>images</span> <span style=''>for</span> <span style=''>further</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>study</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Finding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Differentially</span> <span style=''>Covarying</span> <span style=''>Needles</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Temporally</span> <span style=''>Evolving</span> <span style=''>Haystack</span> <span style=''>A</span> <span style=''>Scan</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perspective</span> <br/><br/><span style=''>Recent</span> <span style=''>results</span> <span style=''>in</span> <span style=''>coupled</span> <span style=''>or</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>offer</span> <span style=''>schemes</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>between</span> <span style=''>features</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>come</span> <span style=''>from</span> <span style=''>related</span> <span style=''>(but</span> <span style=''>distinct)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>longitudinal</span> <span style=''>sources</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>these</span> <span style=''>ideas</span> <span style=''>is</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>group</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>ie</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>if</span> <span style=''>trends</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>objects</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices)</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disparate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>(eg</span> <span style=''>gender</span> <span style=''>or</span> <span style=''>disease)</span> <span style=''>Often</span> <span style=''>poor</span> <span style=''>effect</span> <span style=''>sizes</span> <span style=''>make</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detecting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>signal</span> <span style=''>over</span> <span style=''>the</span> <span style=''>full</span> <span style=''>set</span> <span style=''>of</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>example</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>between</span> <span style=''>only</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>features</span> <span style=''>may</span> <span style=''>manifest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differently</span> <span style=''>across</span> <span style=''>groups</span> <span style=''>In</span> <span style=''>this</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>From</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Stochastic</span> <span style=''>Mixability</span> <span style=''>to</span> <span style=''>Fast</span> <span style=''>Rates</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>(ERM)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>learning</span> <span style=''>rule</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.33054393305439334);'>statistical</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.326530612244898);'>generated</span> <span style='background-color:rgba(0, 255, 0, 0.4630872483221476);'>according</span> <span style=''>to</span> <span style=''>some</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>mathsfP</span> <span style=''>and</span> <span style=''>returns</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>f</span> <span style=''>chosen</span> <span style=''>from</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>class</span> <span style=''>mathcalF</span> <span style=''>with</span> <span style=''>small</span> <span style=''>loss</span> <span style=''>ell</span> <span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4743589743589743);'>parametric</span> <span style=''>setting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>upon</span> <span style=''>(ell</span> <span style=''>mathcalFmathsfP)</span> <span style=''>ERM</span> <span style=''>can</span> <span style=''>have</span> <span style=''>slow</span> <span style=''>(1sqrtn)</span> <span style=''>or</span> <span style=''>fast</span> <span style=''>(1n)</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.35774647887323935);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>There</span> <span style=''>exist</span> <span style=''>several</span> <span style=''>results</span> <span style=''>that</span> <span style=''>give</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style=''>fast</span> <span style=''>rates</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>ell</span> <span style=''>mathcalF</span> <span style=''>and</span> <span style=''>mathsfP</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Bernstein</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>In</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.33054393305439334);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Linear</span> <span style=''>Bandits</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>linear</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>proceeds</span> <span style=''>in</span> <span style=''>rounds</span> <span style=''>where</span> <span style=''>at</span> <span style=''>each</span> <span style=''>round</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>selects</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>from</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>set</span> <span style=''>after</span> <span style=''>which</span> <span style=''>it</span> <span style=''>receives</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>linear</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>by</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>vector</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>such</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>(pseudo)</span> <span style=''>regret</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difference</span> <span style=''>between</span> <span style=''>the</span> <span style=''>total</span> <span style=''>expected</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>total</span> <span style=''>expected</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style=''>fixed</span> <span style=''>vector</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hindsight</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>the</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>eg</span> <span style=''>sparse</span> <span style=''>group</span> <span style=''>sparse</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>captured</span> <span style=''>by</span> <span style=''>a</span> <span style=''>norm</span> <span style=''>eg</span> <span style=''>L</span> <span style=''>1</span> <span style=''>L</span> <span style=''>(12)</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ellipsoids</span> <span style=''>which</span> <span style=''>contain</span> <span style=''>the</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>across</span> <span style=''>all</span> <span style=''>rounds</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1326241134751773)
# 	evaluation (0.09929078014184398)
# 	knowledge (0.12659574468085105)
# 	architecture (0.08865248226950355)
# 	information (0.2429078014184397)
# 	segmentation (0.06843971631205674)
# 	different (0.26560283687943265)
# 	convolutional (0.12127659574468085)
# 	detection (0.1276595744680851)
# 	recognition (0.13900709219858157)
#
# Some Statistics words are:
# 	distributions (0.12222222222222222)
# 	variables (0.14292929292929293)
# 	statistical (0.1606060606060606)
# 	estimation (0.17626262626262626)
# 	theoretical (0.16414141414141414)
# 	distribution (0.18131313131313131)
# 	algorithm (0.40606060606060607)
# 	dimensional (0.18686868686868688)
# 	regression (0.16666666666666666)
# 	inference (0.19595959595959597)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d169e676-dab1-47c3-8c72-b7057960cc6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d169e676-dab1-47c3-8c72-b7057960cc6c")) {                    Plotly.newPlot(                        "d169e676-dab1-47c3-8c72-b7057960cc6c",                        [{"x":["selecting","recognition","irrelevant","challenge","individual","descriptors","distinctions","available","similarity","supervised","selection","understanding","framework","improvements","dimensionality","thresholding","efficiency","multipartite","projection","considerable","performance","instances","successful","correlated","dimensional","redundant","experiments","application","manifolds","requiring","knowledge","demonstrate","geometric","algorithm","generated","gradients","geodesically","averaging","accessible","riemannian","converging","achieving","stochastic","euclidean","minimization","streaming","randomized","accelerate","estimates","transform","convergence","estimators","reasonable","mathematical","detection","estimator","specialized","artificial","efficient","presidential","comparisons","synthetic","regression","probability","generalizes","likelihood","aggregation","elections","algorithms","experimental","classifiers","mechanism","participate","numerical","presented","furthermore","extensive","assumptions","outperform","evaluation","classification","abdominal","introduction","participants","conditional","information","prediction","equations","previously","efficiently","approximates","exponential","posterior","introduce","outperforms","introduces","generalize","variational","threshold","generalization","distribution","important","technical","estimation","difficulties","annotated","structure","unsupervised","significant","quantification","automatic","conducted","tomography","deviation","refinement","appearance","reduction","automated","segmentation","consisting","completely","applications","perceived","reconstruct","preserving","disentangling","continuous","architecture","expression","significantly","manipulating","adversarial","attribute","different","naturalness","attributes","realistic","dependency","benchmarking","concurrent","decomposition","parallelism","implementations","attainable","depending","implement","convolutions","computationally","convolutional","computation","convergent","architectures","compatible","programming","processors","convolution","impossible","preserves","discretization","management","graphical","extremely","principle","distributions","convenient","diagnosis","representing","bioinformatics","description","extensively","relationships","intelligence","expressions","literature","moderately","difficult","variables","importance","financial","dependent","contingent","procedures","forecasting","parameters","timesteps","correlation","inference","quantities","successive","measurements","probabilistic","construct","approximate","conditions","encourage","clustering","covariance","extension","direction","empirical","polynomial","approaches","consistent","multipliers","differences","alternating","subpopulations","precision","laplacian","advantages","potential","heterogeneous","applicability","disparate","parameter","populations","estimated","consistency","dimensions","hierarchical","establish","heterogenous","shrinkage","unlabeled","interpretable","anomalies","optimality","exceptional","interpreted","combination","combining","foundation","detectors","classifier","theoretical","described","simulation","orthogonal","illustrate","analyzing","developments","revisiting","eigenvalue","practical","relevance","comparison","classical","implemented","approximation","developed","collaborations","resulting","scenarios","multimodal","successfully","representatio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	multipartite
# 	reconstructive
# 	debiasing
# 	datastreams
# 	disproportionately
# 	localizes
# 	epanechnikov
# 	autoencoding
# 	smoothers
# 	gaussianity
# 	subsampling
# 	integrands
# 	biomarkers
# 	exchangeability
# 	attributing
# 	procrustes
# 	accumulate
# 	hermitian
# 	stabilisation
# 	layerwise
# Some words which never appear in Statistics papers:
# 	refinement
# 	naturalness
# 	concurrent
# 	illumination
# 	registering
# 	deblurring
# 	cartographic
# 	compilation
# 	evidences
# 	attending
# 	acquisitions
# 	reflection
# 	corporate
# 	informational
# 	milliseconds
# 	furniture
# 	microsoft
# 	supervoxels
# 	focussing
# 	metaphors

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0484087306426047e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
